# %%
# %%time
from ToyMaker import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# CPU times: user 1.22 s, sys: 1.12 s, total: 2.34 s
# Wall time: 1.16 s

# %%
# %%time
n1 = 3.5
n2 = 3.5
k1 = 4400 
k2 = 8080
γr1 = 1/5
γr2 = 50/251
β1 = 216/125
β2 = 216/125
kp1 = 50 
kp2 = 45
γp1 = 1/45
γp2 = 1/45

# Species
def p1(p1): return p1
def p2(p2): return p2

# Propensities
def s1 (p2) : return β1 * ((p2**n1) / (k1**n1 + p2**n1))
def s2 (r1) : return γr1 * r1
def s3 (p1) : return β2/(1 + (p1/k2)**n2)
def s4 (r2) : return γr2 * r2
def s5 (r1) : return kp1 * r1
def s6 (p1) : return γp1 * p1
def s7 (r2) : return kp2 * r2
def s8 (p2) : return γp2 * p2

# Species
species = {
            't':    0., 
            'cell': 0, 
            p1:   0., 
            p2:   0., 
            'r1':   0., 
            'r2':   0.}

reactions = {
            s1: {'create':    ['r1']},
            s2: {'destroy':   ['r1']},
            s3: {'create':    ['r2']},
            s4: {'destroy':   ['r2']},
            s5: {'create':    ['p1']},
            s6: {'destroy':   ['p1']},
            s7: {'create':    ['p2']},
            s8: {'destroy':   ['p2']}
}

tmax = 1000
sampling_time = 1
samples = 1000

# multiple_Cells(species, reactions, tmax, sampling_time, cells=samples, file_name='./simulations/Tactic_model_sim_10000');
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 16.5 µs

# %%
path = './simulations/'
file = 'Tactic_model_sim_10000.csv'

complete_path = path + file
df = pd.read_csv(complete_path)
df.columns
# Out:
# Index(['t', 'cell', 'p1', 'p2', 'r1', 'r2'], dtype='object')

# %%
fig, ax = plt.subplots(figsize=(20, 5), dpi=80)
[plt.plot(df['t'][df['cell'] == 0], df['p1'][df['cell'] == c], color='blue', lw=0.5, alpha=0.1) for c in range(1000)];
[plt.plot(df['t'][df['cell'] == 0], df['p2'][df['cell'] == c], color='black', lw=0.5, alpha=0.1) for c in range(1000)];

# %%
from joblib import Parallel, delayed
def f(x):
    return x ** 0.5
a = Parallel(n_jobs=3)(delayed(f)(i) for i in range(10))
a
# Out:
# [0.0,
#  1.0,
#  1.4142135623730951,
#  1.7320508075688772,
#  2.0,
#  2.23606797749979,
#  2.449489742783178,
#  2.6457513110645907,
#  2.8284271247461903,
#  3.0]
